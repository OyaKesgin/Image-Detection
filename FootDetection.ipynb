# %% [markdown]
# ### Foot Detection

# %%
import cv2
import imutils
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from imageai.Detection.Custom import CustomObjectDetection
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox

# %%
im = cv2.imread('hoxton_mall_entrance_2021-02-05.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
# Out:
# ...
#   0% |                                                                        |
# ...
#  99% |####################################################################### |
# ...
# 100% |                                                                        |

# %%
im = cv2.imread('hoxton_mall_entrance_2021-02-07.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %%
im = cv2.imread('hoxton_mall_entrance_2021-02-15.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %%
im = cv2.imread('hoxton_mall_entrance_2021-02-13.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %%
im = cv2.imread('hoxton_mall_entrance_2021-02-11.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %%
im = cv2.imread('hoxton_mall_entrance_2021-02-09.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
